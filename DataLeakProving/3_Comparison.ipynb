# %%
import numpy as np
import pandas as pd

# %%
exam_y = pd.read_csv("src/data/exam_y.csv")
y_pred = pd.read_csv("src/data/y_pred.csv")
y_pred_hpt = pd.read_csv("src/data/y_pred_hpt.csv")

print(exam_y.shape, y_pred.shape)

from sklearn.metrics import accuracy_score

accuracy = accuracy_score(exam_y, y_pred)
print(f"Accuracy: {accuracy:.4f}")
accuracy_hpt = accuracy_score(exam_y, y_pred_hpt)
print(f"Hyperparameter Tuned Accuracy: {accuracy_hpt:.4f}")
# Out:
# (31794, 1) (31794, 1)
# Accuracy: 0.9584
# Hyperparameter Tuned Accuracy: 0.9719
