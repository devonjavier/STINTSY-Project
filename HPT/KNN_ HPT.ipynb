# %%
from src.trainEvalKNN import hyperparameter_random_search_knn
import lfs_data
p_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'p': [1, 2], 
}

knn_p_grid = hyperparameter_random_search_knn(folds_data, p_grid, n_iter_search=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from src.trainEvalKNN import hyperparameter_random_search_knn
# ----> 2 import lfs_data
#       3 p_grid = {
#       4     'n_neighbors': [3, 5, 7, 9, 11],
#       5     'weights': ['uniform', 'distance'],
#       6     'p': [1, 2],
#       7 }
#       9 folds_data = prepare_data_kfold(lfs_data, target_col = target_col,
#      10                          n_splits = n_splits,
#      11                          missing_value = missing_value,
#      12                          categorical_cols = categorical_cols,
#      13                          feature_cols = feature_cols,
#      14                          seed = seed)
#
# ModuleNotFoundError: No module named 'lfs_data'
